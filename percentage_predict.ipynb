# %%
#importing python library

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# importing data-set

# %%
data = pd.read_csv("C:\\Users\\Inspiron\\Documents\\python\\data.csv")
print("importing data successfully")
# Out:
# importing data successfully

# %% [markdown]
# check whether data imported successfully or not?

# %%
print("for this we print first 10 data Data-Set")
data.head(3)
# Out:
# for this we print first 10 data Data-Set
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27

# %% [markdown]
# plot the graph for detail analysis of data set

# %%
data.plot(x='Hours' ,y = 'Scores' ,style = '1')
plt.title('Hours Vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
data.plot.pie(x='Hours' , y = 'Scores')
# Out:
# <Axes: ylabel='Scores'>

# %%
data.plot.scatter(x='Hours',y='Scores')
# Out:
# <Axes: xlabel='Hours', ylabel='Scores'>

# %%
data.plot.bar(x='Hours',y='Scores')
# Out:
# <Axes: xlabel='Hours'>

# %%
data.sort_values(['Hours'] ,axis = 0, ascending = [True],inplace = True)
print(data)
data.plot.bar(x='Hours', y ='Scores')
# Out:
#     Hours  Scores
# 14    1.1      17
# 5     1.5      20
# 17    1.9      24
# 0     2.5      21
# 16    2.5      30
# 20    2.7      30
# 9     2.7      25
# 2     3.2      27
# 13    3.3      42
# 4     3.5      30
# 22    3.8      35
# 12    4.5      41
# 21    4.8      54
# 1     5.1      47
# 7     5.5      60
# 11    5.9      62
# 18    6.1      67
# 23    6.9      76
# 19    7.4      69
# 10    7.7      85
# 24    7.8      86
# 8     8.3      81
# 3     8.5      75
# 15    8.9      95
# 6     9.2      88
# <Axes: xlabel='Hours'>

# %%
pip install -U scikit-learn scipy matplotlib
# Out:
# ...
#
# ...

# %%
After ploting different graph , we have observed that as Study Hours increases , score is also increase. Which is good sign of correct data. In our daily life , we have observe the same phenomenon.

# %%
Now, we have prepared tha data for our model

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:,1].values

# %%
Now , we have divide the data for tarining & testing the model

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state = 0)

# %% [markdown]
# Training The Algorithm

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
print("Training Complete")
# Out:
# Training Complete

# %%
Now, our Model is ready . Its time to test it .

# %%
print(X_test) 
print("Predection of Score")
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [[2.7]
#  [1.9]
#  [7.7]
#  [6.1]
#  [4.5]]
# Predection of Score
# [28.6177145  20.88803334 76.92822173 61.46885942 46.0094971 ]

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  

df
# Out:
#    Actual  Predicted
# 0      30  28.617714
# 1      24  20.888033
# 2      85  76.928222
# 3      67  61.468859
# 4      41  46.009497

# %%
Now, Its times to prediction with custom input

# %%
hours = [[9.25]]
pred = regressor.predict(hours)
print(pred)
# Out:
# [91.90447898]

# %% [markdown]
# # Evaluating the model

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.621333622532765
